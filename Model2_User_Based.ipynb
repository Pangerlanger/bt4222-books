# %% [markdown]
# # User-Based Collaborative Filtering

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Read Data

# %%
df_books_final = pd.read_csv('df_books_final.csv')
df_train_interactions = pd.read_csv('train_interactions.csv')
df_test_interactions = pd.read_csv('test_interactions.csv')

# %%
df_books_final.head(3)
# Out:
#    book_id                                              title  \
# 0  1882090                     Behave Yourself, Bethany Brant
# 1   166120    Ghosthunters And The Incredibly Revolting Ghost
# 2  8608741  Attack of the Chicken Nugget Man: A National T...
#
#                                          description  average_rating  \
# 0  A preacher's daughter with lots of curiosity a...       -1.028630
# 1  A $2.99 value-priced edition of one of our bes...       -0.690046
# 2  Third-grader Chris Robb just can't seem to do ...       -0.597705
#
#    ratings_count  text_reviews_count  \
# 0      -0.059069           -0.136278
# 1      -0.059069           -0.126186
# 2      -0.059069           -0.102639
#
#                                  top_popular_shelves   author_ids  \
# 0  [{'count': '1', 'name': 'mrs-withdrawn'}, {'co...   ['151369']
# 1  [{'count': '9', 'name': 'owned'}, {'count': '9...    ['15873']
# 2  [{'count': '2', 'name': 'books-i-wrote'}, {'co...  ['2868520']
#
#    format_Audio  format_Digital  ...  lang_tha  lang_tr  lang_tur  lang_ukr  \
# 0         False           False  ...     False    False     False     False
# 1         False           False  ...     False    False     False     False
# 2         False           False  ...     False    False     False     False
#
#    lang_vi  lang_vie  lang_zh  length_long  length_medium  length_short
# 0    False     False    False        False           True         False
# 1    False     False    False        False           True         False
# 2    False     False    False        False           True         False
#
# [3 rows x 84 columns]

# %%
df_train_interactions.head(5)
# Out:
#    user_id  book_id  rating                 date_added  n_votes  review_age  \
# 0        0   157993       5  2016-07-18 19:34:48+00:00      NaN        3004
# 1        0   359079       4  2014-07-16 19:28:57+00:00      NaN        3737
# 2        0    41684       4  2014-07-16 13:45:50+00:00      NaN        3738
# 3        0   180617       4  2012-08-06 19:55:50+00:00      NaN        4446
# 4        0    13023       3  2012-01-30 10:17:30+00:00      NaN        4636
#
#    sentiment
# 0   0.574139
# 1   0.527973
# 2   0.527973
# 3   0.527973
# 4   0.406860

# %% [markdown]
# ## Creating Affinity Matrix Based on Ratings

# %%
# number of neighbors of user
N_NEIGHBORS = 10

# number of recommendations
N_RECOMMENDATIONS = 5

# %%
def read_ratings(df):
    """
    Read the raw data of the book ratings.

    Returns a list of tuples:
    (user id, book_id, rating)
    """

    data = []
    for _, row in df.iterrows():
        user_id = row['user_id']
        book_id = row['book_id']
        rating = row['rating']
        data.append((user_id, book_id, rating))

    return data

# %%
ratings = read_ratings(df_train_interactions)
ratings = pd.DataFrame(data=ratings, columns=['user', 'book', 'rating'])
ratings.head()
# Out:
#    user    book  rating
# 0     0  157993       5
# 1     0  359079       4
# 2     0   41684       4
# 3     0  180617       4
# 4     0   13023       3

# %%
ratings = ratings.pivot(index='user', columns='book', values='rating')

# %%
ratings.shape
# Out:
# (20798, 14645)

# %%
ratings.head(10)
# Out:
# book  5         50        93        236       244       302       314       \
# user
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          5.0       NaN       NaN       NaN       NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4          3.0       NaN       NaN       NaN       NaN       NaN       NaN
# 5          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6          3.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7          NaN       4.0       NaN       NaN       NaN       NaN       NaN
# 8          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9          4.0       NaN       NaN       NaN       NaN       NaN       NaN
#
# book  330       881       903       ...  35297101  35429280  35440603  \
# user                                ...
# 0          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 3          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 4          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 5          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 6          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 7          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 8          NaN       NaN       NaN  ...       NaN       NaN       NaN
# 9          NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# book  35479935  35546694  35616438  35757340  35757419  36131198  36311957
# user
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9          NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [10 rows x 14645 columns]

# %% [markdown]
# ## Similarity between users

# %%
def pearson_similarity(v1, v2):
    """
    Compute the Pearson correlation between to ratings vectors.

    pd.corr() function can handle missing data.

    parameters:
    - v1, v2: pd.Series, ratings vectors

    returns:
    - float

    """

    pearson = v1.corr(v2)

    return pearson

# %%
def compute_similarities(user_id, ratings_matrix):
    """
    Compute the similarity of a given user with all the other users in the dataset.

    Remove the similarity value for the given user from the result.

    returns:
        - a pd.Series with the user id's as index, and similarity as series values
    """

    # get ratings of user to re-use in the similarity computation
    ratings_user = ratings_matrix.loc[user_id,:]

    # calculate the similarity between the given user and the other users
    similarities = ratings_matrix.apply(
        lambda row: pearson_similarity(ratings_user, row),
        axis=1)

    similarities = similarities.to_frame(name='similarity')

    # find most similar users to the given user
    similarities = similarities.sort_values(by='similarity', ascending=False)

    # drop the similarity of the user (should be ~1 anyways)
    similarities = similarities.drop(user_id)

    return similarities

# %% [markdown]
# ## Predict Book Rating

# %%
def predict_rating(item_id, ratings, similarities, N=10):
    """
    Predict the rating of a given item by a user, given the ratings of similar users.
    Takes the N users with the highest similarity measure, AND who have rated the given item.
    Returns the average rating of the most similar users who previously rated the item.

    parameters:
    - item_id: int, item that needs a rating prediction
    - ratings: pd.DataFrame
    - similarities: pd.DataFrame
    - N: int, number of neighbors to use for rating prediction

    returns:
    - a float representing the predicted rating for the given item

    """

    # get the ratings of all users for the specific item
    users_ratings = ratings.loc[:, item_id]

    # only keep users who rated the given item, otherwise you won't be able to generate a prediction based on the users ratings
    most_similar_users_who_rated_item = similarities.loc[~users_ratings.isnull()]

    # keep N users with highest similarities to given user who also rated the given item
    N_most_similar_users = most_similar_users_who_rated_item.head(N)

    # find ratings item for most similar users:
    ratings_for_item = ratings.loc[N_most_similar_users.index, item_id]

    # predict the rating of the item by averaging the ratings of that item of the most similar users
    return item_id, ratings_for_item.mean(), len(ratings_for_item)

# %% [markdown]
# ## Recommend function

# %%
def recommend(user_id, ratings, n_neighbors=10, n_recomm=5):
    """

    Recommend N books for a given user based on ratings data.

    1. get the ratings of the user
    2. get the books that the user has not rated
    3. compute the similarities between the user and the other users
    4. generate book ratings predictions for the user based on the similarities with other users
    5. find the N books with the highest predicted ratings

    parameters:
    - user_id: int, user to generate recommendations for
    - ratings: pd.DataFrame, user-book ratings
    - book_titles: dict, mapping of (book id -> book title)
    - n_neighbors: int: the number of neighbors to use to generate rating predictions
    - n_recomm: int, number of books to recommend

    returns:
    - pd.DataFrame with [book_id, rating, book title]

    """

    # get the ratings of the user
    ratings_user = ratings.loc[user_id, :]

    # all the items a user has not rated, that can be recommended
    all_items = ratings.loc[user_id,:]
    unrated_items = all_items.loc[all_items.isnull()]

    # convert the index with item ids into Series values
    unrated_items = unrated_items.index.to_series(name='item_ids').reset_index(drop=True)
    print('User {} has {} unrated items.'.format(user_id, len(unrated_items)))

    # compute user similarities
    similarities = compute_similarities(user_id, ratings)

    # generate predictions for unseen items based on the user similarity data
    predictions = unrated_items.apply(lambda d: predict_rating(d, ratings, similarities, N=n_neighbors))
    predicitions_df = pd.DataFrame(predictions.tolist(), columns=['book_id', 'predictions', 'number_of_similar_users'])

    # sort items by highest predicted rating and number of similar users
    predicitions_df = predicitions_df.sort_values(by=['predictions', 'number_of_similar_users'], ascending=False)

    # recommend top N items
    recommends = predicitions_df.head(n_recomm)

    return recommends['book_id']

# %% [markdown]
# ## Similarity Matrix

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_scores =  tfidf.fit_transform(df_books_final['description'])
tfidf_scores.shape
# Out:
# (59828, 149225)

# %%
# cosine similarity matrix directly for the sparse TF-IDF matrix
tfidf_cos_sim = cosine_similarity(tfidf_scores, dense_output=False)

# %% [markdown]
# ## Recommend for users in test set

# %%
from statistics import mean 
import warnings
warnings.filterwarnings('ignore')

unique_users = df_test_interactions.user_id.unique()
first1000_users = unique_users[:1000]
results = []

for user in first1000_users:
    recommends = recommend(user, ratings, n_neighbors=N_NEIGHBORS, n_recomm=N_RECOMMENDATIONS)
    test_books = df_test_interactions[df_test_interactions['user_id'] == user]['book_id']
    similarity_scores_list = []
    max_similarity_scores_list = []

    for test_book in test_books:
        similarity_scores_list_temp=[]
        test_book_index = df_books_final.index[df_books_final['book_id'] == test_book][0]
        similarity_scores = tfidf_cos_sim[test_book_index].toarray().flatten()

        for recommended_book in recommends:
            index = df_books_final.index[df_books_final['book_id'] == recommended_book][0]
            similarity_scores_list_temp.append(similarity_scores[index])
        
        
        max_similarity_score = max(similarity_scores_list_temp) if similarity_scores_list_temp else None
        max_similarity_scores_list.append(max_similarity_score)
        similarity_scores_list.extend(similarity_scores_list_temp)

    results.append({
        "user_id": user,
        "books_id_read": test_books.tolist(),
        "recommendations": recommends.tolist(),
        "similarity_scores_list": similarity_scores_list,
        "mean_similarity_score": mean(similarity_scores_list),
        "max_similarity_score": max_similarity_scores_list
    })

output_df = pd.DataFrame(results)
output_df
# Out:
# User 0 has 14638 unrated items.
# User 1 has 14635 unrated items.
# User 2 has 14638 unrated items.
# User 3 has 14633 unrated items.
# User 4 has 14638 unrated items.
# User 5 has 14633 unrated items.
# User 6 has 14638 unrated items.
# User 7 has 14641 unrated items.
# User 8 has 14632 unrated items.
# User 9 has 14635 unrated items.
# User 10 has 14637 unrated items.
# User 11 has 14641 unrated items.
# User 12 has 14638 unrated items.
# User 13 has 14640 unrated items.
# User 14 has 14634 unrated items.
# User 15 has 14636 unrated items.
# User 16 has 14637 unrated items.
# User 17 has 14639 unrated items.
# User 18 has 14640 unrated items.
# User 19 has 14637 unrated items.
# User 20 has 14641 unrated items.
# User 21 has 14632 unrated items.
# User 22 has 14640 unrated items.
# User 23 has 14642 unrated items.
# User 24 has 14638 unrated items.
# User 25 has 14641 unrated items.
# User 26 has 14637 unrated items.
# User 27 has 14640 unrated items.
# User 28 has 14637 unrated items.
# User 29 has 14642 unrated items.
# User 30 has 14641 unrated items.
# User 31 has 14641 unrated items.
# User 32 has 14640 unrated items.
# User 33 has 14642 unrated items.
# User 34 has 14638 unrated items.
# User 35 has 14642 unrated items.
# User 36 has 14636 unrated items.
# User 37 has 14642 unrated items.
# User 38 has 14639 unrated items.
# User 39 has 14641 unrated items.
# User 40 has 14635 unrated items.
# User 41 has 14640 unrated items.
# User 42 has 14639 unrated items.
# User 43 has 14640 unrated items.
# User 44 has 14640 unrated items.
# User 45 has 14641 unrated items.
# User 46 has 14635 unrated items.
# User 47 has 14641 unrated items.
# User 48 has 14635 unrated items.
# User 49 has 14633 unrated items.
# User 50 has 14637 unrated items.
# User 51 has 14642 unrated items.
# User 52 has 14632 unrated items.
# User 53 has 14642 unrated items.
# User 54 has 14640 unrated items.
# User 55 has 14642 unrated items.
# User 56 has 14642 unrated items.
# User 57 has 14633 unrated items.
# User 58 has 14641 unrated items.
# User 59 has 14642 unrated items.
# User 60 has 14639 unrated items.
# User 61 has 14632 unrated items.
# User 62 has 14633 unrated items.
# User 63 has 14642 unrated items.
# User 64 has 14641 unrated items.
# User 65 has 14637 unrated items.
# User 66 has 14642 unrated items.
# User 67 has 14642 unrated items.
# User 68 has 14639 unrated items.
# User 69 has 14632 unrated items.
# User 70 has 14639 unrated items.
# User 71 has 14633 unrated items.
# User 72 has 14637 unrated items.
# User 73 has 14637 unrated items.
# User 74 has 14632 unrated items.
# User 75 has 14641 unrated items.
# User 76 has 14640 unrated items.
# User 77 has 14640 unrated items.
# User 78 has 14634 unrated items.
# User 79 has 14641 unrated items.
# User 80 has 14637 unrated items.
# User 81 has 14633 unrated items.
# User 82 has 14639 unrated items.
# User 83 has 14638 unrated items.
# User 84 has 14637 unrated items.
# User 85 has 14637 unrated items.
# User 86 has 14640 unrated items.
# User 87 has 14640 unrated items.
# User 88 has 14635 unrated items.
# User 89 has 14641 unrated items.
# User 90 has 14641 unrated items.
# User 91 has 14642 unrated items.
# User 92 has 14641 unrated items.
# User 93 has 14642 unrated items.
# User 94 has 14640 unrated items.
# User 95 has 14637 unrated items.
# User 96 has 14641 unrated items.
# User 97 has 14639 unrated items.
# User 98 has 14638 unrated items.
# User 99 has 14637 unrated items.
# User 100 has 14640 unrated items.
# User 101 has 14639 unrated items.
# User 102 has 14634 unrated items.
# User 103 has 14634 unrated items.
# User 104 has 14639 unrated items.
# User 105 has 14633 unrated items.
# User 106 has 14640 unrated items.
# User 107 has 14636 unrated items.
# User 108 has 14639 unrated items.
# User 109 has 14639 unrated items.
# User 110 has 14642 unrated items.
# User 111 has 14633 unrated items.
# User 112 has 14640 unrated items.
# User 113 has 14642 unrated items.
# User 114 has 14638 unrated items.
# User 115 has 14642 unrated items.
# User 116 has 14632 unrated items.
# User 117 has 14636 unrated items.
# User 118 has 14639 unrated items.
# User 119 has 14638 unrated items.
# User 120 has 14640 unrated items.
# User 121 has 14638 unrated items.
# User 122 has 14640 unrated items.
# User 123 has 14641 unrated items.
# User 124 has 14638 unrated items.
# User 125 has 14636 unrated items.
# User 126 has 14636 unrated items.
# User 127 has 14633 unrated items.
# User 128 has 14637 unrated items.
# User 129 has 14634 unrated items.
# User 130 has 14637 unrated items.
# User 131 has 14638 unrated items.
# User 132 has 14635 unrated items.
# User 133 has 14640 unrated items.
# User 134 has 14642 unrated items.
# User 135 has 14641 unrated items.
# User 136 has 14641 unrated items.
# User 137 has 14632 unrated items.
# User 138 has 14641 unrated items.
# User 139 has 14639 unrated items.
# User 140 has 14635 unrated items.
# User 141 has 14636 unrated items.
# User 142 has 14642 unrated items.
# User 143 has 14640 unrated items.
# User 144 has 14635 unrated items.
# User 145 has 14642 unrated items.
# User 146 has 14638 unrated items.
# User 147 has 14642 unrated items.
# User 148 has 14640 unrated items.
# User 149 has 14637 unrated items.
# User 150 has 14632 unrated items.
# User 151 has 14640 unrated items.
# User 152 has 14641 unrated items.
# User 153 has 14639 unrated items.
# User 154 has 14642 unrated items.
# User 155 has 14638 unrated items.
# User 156 has 14642 unrated items.
# User 157 has 14642 unrated items.
# User 158 has 14641 unrated items.
# User 159 has 14633 unrated items.
# User 160 has 14636 unrated items.
# User 161 has 14639 unrated items.
# User 162 has 14642 unrated items.
# User 163 has 14632 unrated items.
# User 164 has 14634 unrated items.
# User 165 has 14641 unrated items.
# User 166 has 14641 unrated items.
# User 167 has 14637 unrated items.
# User 168 has 14634 unrated items.
# User 169 has 14633 unrated items.
# User 170 has 14642 unrated items.
# User 171 has 14637 unrated items.
# User 172 has 14641 unrated items.
# User 173 has 14642 unrated items.
# User 174 has 14638 unrated items.
# User 175 has 14641 unrated items.
# User 176 has 14634 unrated items.
# User 177 has 14642 unrated items.
# User 178 has 14642 unrated items.
# User 179 has 14641 unrated items.
# User 180 has 14642 unrated items.
# User 181 has 14635 unrated items.
# User 182 has 14639 unrated items.
# User 183 has 14637 unrated items.
# User 184 has 14637 unrated items.
# User 185 has 14640 unrated items.
# User 186 has 14639 unrated items.
# User 187 has 14637 unrated items.
# User 188 has 14640 unrated items.
# User 189 has 14642 unrated items.
# User 190 has 14641 unrated items.
# User 191 has 14641 unrated items.
# User 192 has 14642 unrated items.
# User 193 has 14641 unrated items.
# User 194 has 14641 unrated items.
# User 195 has 14639 unrated items.
# User 196 has 14636 unrated items.
# User 197 has 14640 unrated items.
# User 198 has 14642 unrated items.
# User 199 has 14637 unrated items.
# User 200 has 14634 unrated items.
# User 201 has 14642 unrated items.
# User 202 has 14642 unrated items.
# User 203 has 14640 unrated items.
# User 204 has 14635 unrated items.
# User 205 has 14632 unrated items.
# User 206 has 14642 unrated items.
# User 207 has 14639 unrated items.
# User 208 has 14637 unrated items.
# User 209 has 14636 unrated items.
# User 210 has 14638 unrated items.
# User 211 has 14632 unrated items.
# User 212 has 14640 unrated items.
# User 213 has 14638 unrated items.
# User 214 has 14642 unrated items.
# User 215 has 14642 unrated items.
# User 216 has 14642 unrated items.
# User 217 has 14635 unrated items.
# User 218 has 14636 unrated items.
# User 219 has 14638 unrated items.
# User 220 has 14636 unrated items.
# User 221 has 14642 unrated items.
# User 222 has 14640 unrated items.
# User 223 has 14642 unrated items.
# User 224 has 14632 unrated items.
# User 225 has 14642 unrated items.
# User 226 has 14641 unrated items.
# User 227 has 14641 unrated items.
# User 228 has 14637 unrated items.
# User 229 has 14641 unrated items.
# User 230 has 14634 unrated items.
# User 231 has 14642 unrated items.
# User 232 has 14635 unrated items.
# User 233 has 14632 unrated items.
# User 234 has 14639 unrated items.
# User 235 has 14641 unrated items.
# User 236 has 14632 unrated items.
# User 237 has 14641 unrated items.
# User 238 has 14642 unrated items.
# User 239 has 14638 unrated items.
# User 240 has 14642 unrated items.
# User 241 has 14639 unrated items.
# User 242 has 14642 unrated items.
# User 243 has 14636 unrated items.
# User 244 has 14641 unrated items.
# User 245 has 14636 unrated items.
# User 246 has 14641 unrated items.
# User 247 has 14639 unrated items.
# User 248 has 14640 unrated items.
# User 249 has 14641 unrated items.
# User 250 has 14642 unrated items.
# User 251 has 14633 unrated items.
# User 252 has 14635 unrated items.
# User 253 has 14639 unrated items.
# User 254 has 14640 unrated items.
# User 255 has 14637 unrated items.
# User 256 has 14639 unrated items.
# User 257 has 14640 unrated items.
# User 258 has 14642 unrated items.
# User 259 has 14637 unrated items.
# User 260 has 14642 unrated items.
# User 261 has 14642 unrated items.
# User 262 has 14640 unrated items.
# User 263 has 14632 unrated items.
# User 264 has 14632 unrated items.
# User 265 has 14632 unrated items.
# User 266 has 14637 unrated items.
# User 267 has 14636 unrated items.
# User 268 has 14639 unrated items.
# User 269 has 14635 unrated items.
# User 270 has 14641 unrated items.
# User 271 has 14636 unrated items.
# User 272 has 14640 unrated items.
# User 273 has 14642 unrated items.
# User 274 has 14633 unrated items.
# User 275 has 14634 unrated items.
# User 276 has 14639 unrated items.
# User 277 has 14641 unrated items.
# User 278 has 14642 unrated items.
# User 279 has 14637 unrated items.
# User 280 has 14641 unrated items.
# User 281 has 14640 unrated items.
# User 282 has 14642 unrated items.
# User 283 has 14640 unrated items.
# User 284 has 14637 unrated items.
# User 285 has 14636 unrated items.
# User 286 has 14641 unrated items.
# User 287 has 14641 unrated items.
# User 288 has 14638 unrated items.
# User 289 has 14641 unrated items.
# User 290 has 14640 unrated items.
# User 291 has 14636 unrated items.
# User 292 has 14642 unrated items.
# User 293 has 14636 unrated items.
# User 294 has 14639 unrated items.
# User 295 has 14641 unrated items.
# User 296 has 14641 unrated items.
# User 297 has 14637 unrated items.
# User 298 has 14641 unrated items.
# User 299 has 14642 unrated items.
# User 300 has 14639 unrated items.
# User 301 has 14638 unrated items.
# User 302 has 14639 unrated items.
# User 303 has 14642 unrated items.
# User 304 has 14642 unrated items.
# User 305 has 14639 unrated items.
# User 306 has 14641 unrated items.
# User 307 has 14642 unrated items.
# User 308 has 14641 unrated items.
# User 309 has 14642 unrated items.
# User 310 has 14642 unrated items.
# User 311 has 14642 unrated items.
# User 312 has 14639 unrated items.
# User 313 has 14640 unrated items.
# User 314 has 14635 unrated items.
# User 315 has 14637 unrated items.
# User 316 has 14637 unrated items.
# User 317 has 14641 unrated items.
# User 318 has 14641 unrated items.
# User 319 has 14638 unrated items.
# User 320 has 14635 unrated items.
# User 321 has 14642 unrated items.
# User 322 has 14637 unrated items.
# User 323 has 14635 unrated items.
# User 324 has 14641 unrated items.
# User 325 has 14632 unrated items.
# User 326 has 14635 unrated items.
# User 327 has 14640 unrated items.
# User 328 has 14632 unrated items.
# User 329 has 14637 unrated items.
# User 330 has 14640 unrated items.
# User 331 has 14642 unrated items.
# User 332 has 14642 unrated items.
# User 333 has 14642 unrated items.
# User 334 has 14635 unrated items.
# User 335 has 14640 unrated items.
# User 336 has 14638 unrated items.
# User 337 has 14637 unrated items.
# User 338 has 14635 unrated items.
# User 339 has 14639 unrated items.
# User 340 has 14637 unrated items.
# User 341 has 14636 unrated items.
# User 342 has 14642 unrated items.
# User 343 has 14639 unrated items.
# User 344 has 14640 unrated items.
# User 345 has 14640 unrated items.
# User 346 has 14636 unrated items.
# User 347 has 14641 unrated items.
# User 348 has 14632 unrated items.
# User 349 has 14638 unrated items.
# User 350 has 14638 unrated items.
# User 351 has 14639 unrated items.
# User 352 has 14639 unrated items.
# User 353 has 14640 unrated items.
# User 354 has 14636 unrated items.
# User 355 has 14639 unrated items.
# User 356 has 14632 unrated items.
# User 357 has 14632 unrated items.
# User 358 has 14639 unrated items.
# User 359 has 14640 unrated items.
# User 360 has 14638 unrated items.
# User 361 has 14640 unrated items.
# User 362 has 14640 unrated items.
# User 363 has 14636 unrated items.
# User 364 has 14639 unrated items.
# User 365 has 14642 unrated items.
# User 366 has 14640 unrated items.
# User 367 has 14642 unrated items.
# User 368 has 14639 unrated items.
# User 369 has 14637 unrated items.
# User 370 has 14635 unrated items.
# User 371 has 14642 unrated items.
# User 372 has 14642 unrated items.
# User 373 has 14636 unrated items.
# User 374 has 14642 unrated items.
# User 375 has 14642 unrated items.
# User 376 has 14642 unrated items.
# User 377 has 14642 unrated items.
# User 378 has 14640 unrated items.
# User 379 has 14640 unrated items.
# User 380 has 14636 unrated items.
# User 381 has 14641 unrated items.
# User 382 has 14640 unrated items.
# User 383 has 14637 unrated items.
# User 384 has 14642 unrated items.
# User 385 has 14634 unrated items.
# User 386 has 14634 unrated items.
# User 387 has 14641 unrated items.
# User 388 has 14639 unrated items.
# User 389 has 14636 unrated items.
# User 390 has 14642 unrated items.
# User 391 has 14632 unrated items.
# User 392 has 14639 unrated items.
# User 393 has 14638 unrated items.
# User 394 has 14638 unrated items.
# User 395 has 14641 unrated items.
# User 396 has 14641 unrated items.
# User 397 has 14639 unrated items.
# User 398 has 14639 unrated items.
# User 399 has 14642 unrated items.
# User 400 has 14642 unrated items.
# User 401 has 14636 unrated items.
# User 402 has 14642 unrated items.
# User 403 has 14642 unrated items.
# User 404 has 14637 unrated items.
# User 405 has 14642 unrated items.
# User 406 has 14640 unrated items.
# User 407 has 14636 unrated items.
# User 408 has 14638 unrated items.
# User 409 has 14639 unrated items.
# User 410 has 14642 unrated items.
# User 411 has 14640 unrated items.
# User 412 has 14639 unrated items.
# User 413 has 14641 unrated items.
# User 414 has 14638 unrated items.
# User 415 has 14642 unrated items.
# User 416 has 14641 unrated items.
# User 417 has 14636 unrated items.
# User 418 has 14640 unrated items.
# User 419 has 14640 unrated items.
# User 420 has 14640 unrated items.
# User 421 has 14639 unrated items.
# User 422 has 14635 unrated items.
# User 423 has 14633 unrated items.
# User 424 has 14632 unrated items.
# User 425 has 14638 unrated items.
# User 426 has 14633 unrated items.
# User 427 has 14642 unrated items.
# User 428 has 14639 unrated items.
# User 429 has 14640 unrated items.
# User 430 has 14641 unrated items.
# User 431 has 14642 unrated items.
# User 432 has 14642 unrated items.
# User 433 has 14641 unrated items.
# User 434 has 14641 unrated items.
# User 435 has 14638 unrated items.
# User 436 has 14641 unrated items.
# User 437 has 14642 unrated items.
# User 438 has 14637 unrated items.
# User 439 has 14641 unrated items.
# User 440 has 14642 unrated items.
# User 441 has 14639 unrated items.
# User 442 has 14642 unrated items.
# User 443 has 14642 unrated items.
# User 444 has 14635 unrated items.
# User 445 has 14641 unrated items.
# User 446 has 14639 unrated items.
# User 447 has 14642 unrated items.
# User 448 has 14636 unrated items.
# User 449 has 14642 unrated items.
# User 450 has 14642 unrated items.
# User 451 has 14637 unrated items.
# User 452 has 14641 unrated items.
# User 453 has 14638 unrated items.
# User 454 has 14641 unrated items.
# User 455 has 14632 unrated items.
# User 456 has 14641 unrated items.
# User 457 has 14638 unrated items.
# User 458 has 14640 unrated items.
# User 459 has 14642 unrated items.
# User 460 has 14634 unrated items.
# User 461 has 14634 unrated items.
# User 462 has 14642 unrated items.
# User 463 has 14641 unrated items.
# User 464 has 14641 unrated items.
# User 465 has 14642 unrated items.
# User 466 has 14633 unrated items.
# User 467 has 14641 unrated items.
# User 468 has 14632 unrated items.
# User 469 has 14642 unrated items.
# User 470 has 14636 unrated items.
# User 471 has 14635 unrated items.
# User 472 has 14633 unrated items.
# User 473 has 14641 unrated items.
# User 474 has 14640 unrated items.
# User 475 has 14641 unrated items.
# User 476 has 14640 unrated items.
# User 477 has 14640 unrated items.
# User 478 has 14637 unrated items.
# User 479 has 14637 unrated items.
# User 480 has 14641 unrated items.
# User 481 has 14640 unrated items.
# User 482 has 14642 unrated items.
# User 483 has 14640 unrated items.
# User 484 has 14633 unrated items.
# User 485 has 14642 unrated items.
# User 486 has 14634 unrated items.
# User 487 has 14640 unrated items.
# User 488 has 14639 unrated items.
# User 489 has 14642 unrated items.
# User 490 has 14633 unrated items.
# User 491 has 14639 unrated items.
# User 492 has 14642 unrated items.
# User 493 has 14637 unrated items.
# User 494 has 14639 unrated items.
# User 495 has 14639 unrated items.
# User 496 has 14642 unrated items.
# User 497 has 14636 unrated items.
# User 498 has 14637 unrated items.
# User 499 has 14637 unrated items.
# User 500 has 14637 unrated items.
# User 501 has 14638 unrated items.
# User 502 has 14642 unrated items.
# User 503 has 14638 unrated items.
# User 504 has 14633 unrated items.
# User 505 has 14638 unrated items.
# User 506 has 14642 unrated items.
# User 507 has 14637 unrated items.
# User 508 has 14639 unrated items.
# User 509 has 14641 unrated items.
# User 510 has 14641 unrated items.
# User 511 has 14642 unrated items.
# User 512 has 14632 unrated items.
# User 513 has 14642 unrated items.
# User 514 has 14638 unrated items.
# User 515 has 14635 unrated items.
# User 516 has 14633 unrated items.
# User 517 has 14635 unrated items.
# User 518 has 14639 unrated items.
# User 519 has 14641 unrated items.
# User 520 has 14642 unrated items.
# User 521 has 14642 unrated items.
# User 522 has 14640 unrated items.
# User 523 has 14642 unrated items.
# User 524 has 14641 unrated items.
# User 525 has 14641 unrated items.
# User 526 has 14641 unrated items.
# User 527 has 14638 unrated items.
# User 528 has 14636 unrated items.
# User 529 has 14638 unrated items.
# User 530 has 14637 unrated items.
# User 531 has 14640 unrated items.
# User 532 has 14642 unrated items.
# User 533 has 14641 unrated items.
# User 534 has 14640 unrated items.
# User 535 has 14638 unrated items.
# User 536 has 14638 unrated items.
# User 537 has 14634 unrated items.
# User 538 has 14636 unrated items.
# User 539 has 14632 unrated items.
# User 540 has 14642 unrated items.
# User 541 has 14640 unrated items.
# User 542 has 14641 unrated items.
# User 543 has 14642 unrated items.
# User 544 has 14641 unrated items.
# User 545 has 14639 unrated items.
# User 546 has 14642 unrated items.
# User 547 has 14640 unrated items.
# User 548 has 14638 unrated items.
# User 549 has 14638 unrated items.
# User 550 has 14642 unrated items.
# User 551 has 14639 unrated items.
# User 552 has 14635 unrated items.
# User 553 has 14642 unrated items.
# User 554 has 14640 unrated items.
# User 555 has 14636 unrated items.
# User 556 has 14637 unrated items.
# User 557 has 14640 unrated items.
# User 558 has 14638 unrated items.
# User 559 has 14640 unrated items.
# User 560 has 14641 unrated items.
# User 561 has 14641 unrated items.
# User 562 has 14634 unrated items.
# User 563 has 14641 unrated items.
# User 564 has 14642 unrated items.
# User 565 has 14642 unrated items.
# User 566 has 14641 unrated items.
# User 567 has 14635 unrated items.
# User 568 has 14642 unrated items.
# User 569 has 14641 unrated items.
# User 570 has 14640 unrated items.
# User 571 has 14640 unrated items.
# User 572 has 14637 unrated items.
# User 573 has 14639 unrated items.
# User 574 has 14640 unrated items.
# User 575 has 14639 unrated items.
# User 576 has 14641 unrated items.
# User 577 has 14634 unrated items.
# User 578 has 14635 unrated items.
# User 579 has 14639 unrated items.
# User 580 has 14640 unrated items.
# User 581 has 14641 unrated items.
# User 582 has 14636 unrated items.
# User 583 has 14635 unrated items.
# User 584 has 14641 unrated items.
# User 585 has 14635 unrated items.
# User 586 has 14636 unrated items.
# User 587 has 14633 unrated items.
# User 588 has 14641 unrated items.
# User 589 has 14639 unrated items.
# User 590 has 14637 unrated items.
# User 591 has 14640 unrated items.
# User 592 has 14641 unrated items.
# User 593 has 14641 unrated items.
# User 594 has 14641 unrated items.
# User 595 has 14638 unrated items.
# User 596 has 14635 unrated items.
# User 597 has 14641 unrated items.
# User 598 has 14641 unrated items.
# User 599 has 14634 unrated items.
# User 600 has 14634 unrated items.
# User 601 has 14638 unrated items.
# User 602 has 14639 unrated items.
# User 603 has 14642 unrated items.
# User 604 has 14639 unrated items.
# User 605 has 14639 unrated items.
# User 606 has 14641 unrated items.
# User 607 has 14642 unrated items.
# User 608 has 14639 unrated items.
# User 609 has 14637 unrated items.
# User 610 has 14637 unrated items.
# User 611 has 14641 unrated items.
# User 612 has 14642 unrated items.
# User 613 has 14640 unrated items.
# User 614 has 14642 unrated items.
# User 615 has 14642 unrated items.
# User 616 has 14642 unrated items.
# User 617 has 14633 unrated items.
# User 618 has 14641 unrated items.
# User 619 has 14633 unrated items.
# User 620 has 14641 unrated items.
# User 621 has 14637 unrated items.
# User 622 has 14641 unrated items.
# User 623 has 14636 unrated items.
# User 624 has 14639 unrated items.
# User 625 has 14642 unrated items.
# User 626 has 14640 unrated items.
# User 627 has 14638 unrated items.
# User 628 has 14641 unrated items.
# User 629 has 14640 unrated items.
# User 630 has 14642 unrated items.
# User 631 has 14641 unrated items.
# User 632 has 14635 unrated items.
# User 633 has 14641 unrated items.
# User 634 has 14635 unrated items.
# User 635 has 14641 unrated items.
# User 636 has 14642 unrated items.
# User 637 has 14638 unrated items.
# User 638 has 14640 unrated items.
# User 639 has 14638 unrated items.
# User 640 has 14641 unrated items.
# User 641 has 14639 unrated items.
# User 642 has 14642 unrated items.
# User 643 has 14638 unrated items.
# User 644 has 14633 unrated items.
# User 645 has 14638 unrated items.
# User 646 has 14639 unrated items.
# User 647 has 14634 unrated items.
# User 648 has 14639 unrated items.
# User 649 has 14639 unrated items.
# User 650 has 14641 unrated items.
# User 651 has 14642 unrated items.
# User 652 has 14640 unrated items.
# User 653 has 14639 unrated items.
# User 654 has 14642 unrated items.
# User 655 has 14640 unrated items.
# User 656 has 14639 unrated items.
# User 657 has 14632 unrated items.
# User 658 has 14642 unrated items.
# User 659 has 14639 unrated items.
# User 660 has 14642 unrated items.
# User 661 has 14636 unrated items.
# User 662 has 14639 unrated items.
# User 663 has 14633 unrated items.
# User 664 has 14642 unrated items.
# User 665 has 14635 unrated items.
# User 666 has 14642 unrated items.
# User 667 has 14638 unrated items.
# User 668 has 14640 unrated items.
# User 669 has 14636 unrated items.
# User 670 has 14642 unrated items.
# User 671 has 14639 unrated items.
# User 672 has 14642 unrated items.
# User 673 has 14640 unrated items.
# User 674 has 14634 unrated items.
# User 675 has 14640 unrated items.
# User 676 has 14632 unrated items.
# User 677 has 14637 unrated items.
# User 678 has 14639 unrated items.
# User 679 has 14641 unrated items.
# User 680 has 14638 unrated items.
# User 681 has 14642 unrated items.
# User 682 has 14640 unrated items.
# User 683 has 14632 unrated items.
# User 684 has 14641 unrated items.
# User 685 has 14639 unrated items.
# User 686 has 14637 unrated items.
# User 687 has 14636 unrated items.
# User 688 has 14637 unrated items.
# User 689 has 14642 unrated items.
# User 690 has 14640 unrated items.
# User 691 has 14640 unrated items.
# User 692 has 14635 unrated items.
# User 693 has 14633 unrated items.
# User 694 has 14632 unrated items.
# User 695 has 14641 unrated items.
# User 696 has 14641 unrated items.
# User 697 has 14640 unrated items.
# User 698 has 14636 unrated items.
# User 699 has 14642 unrated items.
# User 700 has 14640 unrated items.
# User 701 has 14639 unrated items.
# User 702 has 14633 unrated items.
# User 703 has 14638 unrated items.
# User 704 has 14640 unrated items.
# User 705 has 14635 unrated items.
# User 706 has 14641 unrated items.
# User 707 has 14641 unrated items.
# User 708 has 14640 unrated items.
# User 709 has 14642 unrated items.
# User 710 has 14635 unrated items.
# User 711 has 14642 unrated items.
# User 712 has 14636 unrated items.
# User 713 has 14642 unrated items.
# User 714 has 14638 unrated items.
# User 715 has 14633 unrated items.
# User 716 has 14632 unrated items.
# User 717 has 14640 unrated items.
# User 718 has 14636 unrated items.
# User 719 has 14632 unrated items.
# User 720 has 14642 unrated items.
# User 721 has 14639 unrated items.
# User 722 has 14641 unrated items.
# User 723 has 14637 unrated items.
# User 724 has 14632 unrated items.
# User 725 has 14639 unrated items.
# User 726 has 14641 unrated items.
# User 727 has 14641 unrated items.
# User 728 has 14641 unrated items.
# User 729 has 14642 unrated items.
# User 730 has 14637 unrated items.
# User 731 has 14640 unrated items.
# User 732 has 14642 unrated items.
# User 733 has 14639 unrated items.
# User 734 has 14638 unrated items.
# User 735 has 14639 unrated items.
# User 736 has 14635 unrated items.
# User 737 has 14642 unrated items.
# User 738 has 14632 unrated items.
# User 739 has 14642 unrated items.
# User 740 has 14638 unrated items.
# User 741 has 14635 unrated items.
# User 742 has 14636 unrated items.
# User 743 has 14641 unrated items.
# User 744 has 14639 unrated items.
# User 745 has 14642 unrated items.
# User 746 has 14640 unrated items.
# User 747 has 14642 unrated items.
# User 748 has 14641 unrated items.
# User 749 has 14639 unrated items.
# User 750 has 14634 unrated items.
# User 751 has 14642 unrated items.
# User 752 has 14639 unrated items.
# User 753 has 14641 unrated items.
# User 754 has 14637 unrated items.
# User 755 has 14641 unrated items.
# User 756 has 14641 unrated items.
# User 757 has 14641 unrated items.
# User 758 has 14640 unrated items.
# User 759 has 14639 unrated items.
# User 760 has 14642 unrated items.
# User 761 has 14642 unrated items.
# User 762 has 14642 unrated items.
# User 763 has 14637 unrated items.
# User 764 has 14634 unrated items.
# User 765 has 14641 unrated items.
# User 766 has 14634 unrated items.
# User 767 has 14642 unrated items.
# User 768 has 14634 unrated items.
# User 769 has 14641 unrated items.
# User 770 has 14638 unrated items.
# User 771 has 14642 unrated items.
# User 772 has 14639 unrated items.
# User 773 has 14640 unrated items.
# User 774 has 14639 unrated items.
# User 775 has 14642 unrated items.
# User 776 has 14637 unrated items.
# User 777 has 14640 unrated items.
# User 778 has 14637 unrated items.
# User 779 has 14641 unrated items.
# User 780 has 14632 unrated items.
# User 781 has 14642 unrated items.
# User 782 has 14633 unrated items.
# User 783 has 14639 unrated items.
# User 784 has 14639 unrated items.
# User 785 has 14640 unrated items.
# User 786 has 14638 unrated items.
# User 787 has 14634 unrated items.
# User 788 has 14633 unrated items.
# User 789 has 14640 unrated items.
# User 790 has 14641 unrated items.
# User 791 has 14639 unrated items.
# User 792 has 14642 unrated items.
# User 793 has 14642 unrated items.
# User 794 has 14641 unrated items.
# User 795 has 14633 unrated items.
# User 796 has 14641 unrated items.
# User 797 has 14633 unrated items.
# User 798 has 14642 unrated items.
# User 799 has 14637 unrated items.
# User 800 has 14642 unrated items.
# User 801 has 14642 unrated items.
# User 802 has 14641 unrated items.
# User 803 has 14640 unrated items.
# User 804 has 14639 unrated items.
# User 805 has 14632 unrated items.
# User 806 has 14640 unrated items.
# User 807 has 14638 unrated items.
# User 808 has 14635 unrated items.
# User 809 has 14639 unrated items.
# User 810 has 14635 unrated items.
# User 811 has 14637 unrated items.
# User 812 has 14642 unrated items.
# User 813 has 14638 unrated items.
# User 814 has 14636 unrated items.
# User 815 has 14637 unrated items.
# User 816 has 14641 unrated items.
# User 817 has 14642 unrated items.
# User 818 has 14632 unrated items.
# User 819 has 14642 unrated items.
# User 820 has 14642 unrated items.
# User 821 has 14632 unrated items.
# User 822 has 14637 unrated items.
# User 823 has 14634 unrated items.
# User 824 has 14636 unrated items.
# User 825 has 14637 unrated items.
# User 826 has 14640 unrated items.
# User 827 has 14642 unrated items.
# User 828 has 14636 unrated items.
# User 829 has 14641 unrated items.
# User 830 has 14637 unrated items.
# User 831 has 14635 unrated items.
# User 832 has 14637 unrated items.
# User 833 has 14641 unrated items.
# User 834 has 14639 unrated items.
# User 835 has 14641 unrated items.
# User 836 has 14639 unrated items.
# User 837 has 14632 unrated items.
# User 838 has 14634 unrated items.
# User 839 has 14641 unrated items.
# User 840 has 14637 unrated items.
# User 841 has 14637 unrated items.
# User 842 has 14639 unrated items.
# User 843 has 14635 unrated items.
# User 844 has 14639 unrated items.
# User 845 has 14642 unrated items.
# User 846 has 14635 unrated items.
# User 847 has 14637 unrated items.
# User 848 has 14641 unrated items.
# User 849 has 14640 unrated items.
# User 850 has 14642 unrated items.
# User 851 has 14642 unrated items.
# User 852 has 14640 unrated items.
# User 853 has 14637 unrated items.
# User 854 has 14641 unrated items.
# User 855 has 14635 unrated items.
# User 856 has 14641 unrated items.
# User 857 has 14639 unrated items.
# User 858 has 14641 unrated items.
# User 859 has 14641 unrated items.
# User 860 has 14642 unrated items.
# User 861 has 14642 unrated items.
# User 862 has 14635 unrated items.
# User 863 has 14637 unrated items.
# User 864 has 14642 unrated items.
# User 865 has 14633 unrated items.
# User 866 has 14635 unrated items.
# User 867 has 14641 unrated items.
# User 868 has 14634 unrated items.
# User 869 has 14642 unrated items.
# User 870 has 14637 unrated items.
# User 871 has 14632 unrated items.
# User 872 has 14641 unrated items.
# User 873 has 14641 unrated items.
# User 874 has 14642 unrated items.
# User 875 has 14640 unrated items.
# User 876 has 14640 unrated items.
# User 877 has 14641 unrated items.
# User 878 has 14637 unrated items.
# User 879 has 14640 unrated items.
# User 880 has 14642 unrated items.
# User 881 has 14642 unrated items.
# User 882 has 14633 unrated items.
# User 883 has 14641 unrated items.
# User 884 has 14636 unrated items.
# User 885 has 14638 unrated items.
# User 886 has 14639 unrated items.
# User 887 has 14642 unrated items.
# User 888 has 14634 unrated items.
# User 889 has 14636 unrated items.
# User 890 has 14642 unrated items.
# User 891 has 14639 unrated items.
# User 892 has 14635 unrated items.
# User 893 has 14634 unrated items.
# User 894 has 14638 unrated items.
# User 895 has 14637 unrated items.
# User 896 has 14641 unrated items.
# User 897 has 14640 unrated items.
# User 898 has 14641 unrated items.
# User 899 has 14642 unrated items.
# User 900 has 14632 unrated items.
# User 901 has 14641 unrated items.
# User 902 has 14640 unrated items.
# User 903 has 14636 unrated items.
# User 904 has 14642 unrated items.
# User 905 has 14638 unrated items.
# User 906 has 14632 unrated items.
# User 907 has 14638 unrated items.
# User 908 has 14642 unrated items.
# User 909 has 14641 unrated items.
# User 910 has 14638 unrated items.
# User 911 has 14642 unrated items.
# User 912 has 14642 unrated items.
# User 913 has 14639 unrated items.
# User 914 has 14640 unrated items.
# User 915 has 14632 unrated items.
# User 916 has 14642 unrated items.
# User 917 has 14642 unrated items.
# User 918 has 14640 unrated items.
# User 919 has 14641 unrated items.
# User 920 has 14641 unrated items.
# User 921 has 14641 unrated items.
# User 922 has 14641 unrated items.
# User 923 has 14635 unrated items.
# User 924 has 14638 unrated items.
# User 925 has 14642 unrated items.
# User 926 has 14637 unrated items.
# User 927 has 14639 unrated items.
# User 928 has 14642 unrated items.
# User 929 has 14641 unrated items.
# User 930 has 14642 unrated items.
# User 931 has 14637 unrated items.
# User 932 has 14639 unrated items.
# User 933 has 14642 unrated items.
# User 934 has 14636 unrated items.
# User 935 has 14639 unrated items.
# User 936 has 14635 unrated items.
# User 937 has 14641 unrated items.
# User 938 has 14637 unrated items.
# User 939 has 14641 unrated items.
# User 940 has 14642 unrated items.
# User 941 has 14639 unrated items.
# User 942 has 14637 unrated items.
# User 943 has 14632 unrated items.
# User 944 has 14642 unrated items.
# User 945 has 14641 unrated items.
# User 946 has 14641 unrated items.
# User 947 has 14640 unrated items.
# User 948 has 14642 unrated items.
# User 949 has 14642 unrated items.
# User 950 has 14635 unrated items.
# User 951 has 14639 unrated items.
# User 952 has 14634 unrated items.
# User 953 has 14642 unrated items.
# User 954 has 14642 unrated items.
# User 955 has 14639 unrated items.
# User 956 has 14633 unrated items.
# User 957 has 14642 unrated items.
# User 958 has 14640 unrated items.
# User 959 has 14636 unrated items.
# User 960 has 14632 unrated items.
# User 961 has 14638 unrated items.
# User 962 has 14642 unrated items.
# User 963 has 14640 unrated items.
# User 964 has 14633 unrated items.
# User 965 has 14641 unrated items.
# User 966 has 14639 unrated items.
# User 967 has 14633 unrated items.
# User 968 has 14639 unrated items.
# User 969 has 14635 unrated items.
# User 970 has 14641 unrated items.
# User 971 has 14639 unrated items.
# User 972 has 14640 unrated items.
# User 973 has 14634 unrated items.
# User 974 has 14633 unrated items.
# User 975 has 14641 unrated items.
# User 976 has 14638 unrated items.
# User 977 has 14638 unrated items.
# User 978 has 14638 unrated items.
# User 979 has 14640 unrated items.
# User 980 has 14635 unrated items.
# User 981 has 14637 unrated items.
# User 982 has 14637 unrated items.
# User 983 has 14635 unrated items.
# User 984 has 14639 unrated items.
# User 985 has 14633 unrated items.
# User 986 has 14638 unrated items.
# User 987 has 14636 unrated items.
# User 988 has 14642 unrated items.
# User 989 has 14635 unrated items.
# User 990 has 14640 unrated items.
# User 991 has 14641 unrated items.
# User 992 has 14637 unrated items.
# User 993 has 14639 unrated items.
# User 994 has 14634 unrated items.
# User 995 has 14642 unrated items.
# User 996 has 14634 unrated items.
# User 997 has 14640 unrated items.
# User 998 has 14640 unrated items.
# User 999 has 14636 unrated items.
#      user_id         books_id_read  \
# 0          0        [343002, 1852]
# 1          1      [1248128, 30119]
# 2          2      [74595, 2711313]
# 3          3       [30119, 157993]
# 4          4       [13023, 157993]
# ..       ...                   ...
# 995      995        [24178, 78411]
# 996      996      [267972, 275000]
# 997      997  [25618438, 23754884]
# 998      998           [140225, 5]
# 999      999        [157993, 3008]
#
#                                 recommendations  \
# 0    [46677, 867248, 6669717, 22013040, 402114]
# 1     [14118, 46677, 867248, 6669717, 22013040]
# 2    [14118, 867248, 6669717, 22013040, 402114]
# 3     [14118, 46677, 867248, 6669717, 22013040]
# 4     [14118, 46677, 867248, 6669717, 22013040]
# ..                                          ...
# 995   [14118, 46677, 867248, 6669717, 22013040]
# 996   [14118, 46677, 867248, 6669717, 22013040]
# 997   [14118, 46677, 867248, 6669717, 22013040]
# 998   [14118, 46677, 867248, 6669717, 22013040]
# 999   [14118, 46677, 867248, 6669717, 22013040]
#
#                                 similarity_scores_list  mean_similarity_score  \
# 0    [0.02697621518236352, 0.0, 0.03242136805362899...               0.018405
# 1    [0.007197123322763255, 0.0051736136925291925, ...               0.058451
# 2    [0.01044065185339305, 0.0, 0.02950585563320733...               0.009337
# 3    [0.012281415239966146, 0.02696491648561693, 0....               0.066646
# 4    [0.00340888102818777, 0.02332300161231656, 0.0...               0.015926
# ..                                                 ...                    ...
# 995  [0.0426236394204663, 0.02526529716731194, 0.00...               0.019403
# 996  [0.02398428888624259, 0.020906982781366244, 0....               0.010759
# 997  [0.0, 0.015102355213715836, 0.0, 0.02371667758...               0.006078
# 998  [0.011927089756086478, 0.01132274443756136, 0....               0.012094
# 999  [0.020676692215979318, 0.026918746933448458, 0...               0.018199
#
#                              max_similarity_score
# 0      [0.03242136805362899, 0.03906784168008337]
# 1      [0.007197123322763255, 0.5127871656196451]
# 2    [0.029505855633207338, 0.018733342147202403]
# 3        [0.5127871656196451, 0.0517584584988947]
# 4       [0.02332300161231656, 0.0517584584988947]
# ..                                            ...
# 995    [0.0426236394204663, 0.028494710116081803]
# 996   [0.02561423259626288, 0.007984469981907565]
# 997  [0.023716677584827726, 0.006018297839707198]
# 998  [0.029593441500958117, 0.019991562840876765]
# 999     [0.0517584584988947, 0.04519524332308271]
#
# [1000 rows x 6 columns]

# %%
output_df['num_exact_matches'] = output_df.apply(
    lambda row: sum(1 for book_id in row['recommendations'] if book_id in row['books_id_read']),
    axis=1
)
output_df
# Out:
#      user_id         books_id_read  \
# 0          0        [343002, 1852]
# 1          1      [1248128, 30119]
# 2          2      [74595, 2711313]
# 3          3       [30119, 157993]
# 4          4       [13023, 157993]
# ..       ...                   ...
# 995      995        [24178, 78411]
# 996      996      [267972, 275000]
# 997      997  [25618438, 23754884]
# 998      998           [140225, 5]
# 999      999        [157993, 3008]
#
#                                 recommendations  \
# 0    [46677, 867248, 6669717, 22013040, 402114]
# 1     [14118, 46677, 867248, 6669717, 22013040]
# 2    [14118, 867248, 6669717, 22013040, 402114]
# 3     [14118, 46677, 867248, 6669717, 22013040]
# 4     [14118, 46677, 867248, 6669717, 22013040]
# ..                                          ...
# 995   [14118, 46677, 867248, 6669717, 22013040]
# 996   [14118, 46677, 867248, 6669717, 22013040]
# 997   [14118, 46677, 867248, 6669717, 22013040]
# 998   [14118, 46677, 867248, 6669717, 22013040]
# 999   [14118, 46677, 867248, 6669717, 22013040]
#
#                                 similarity_scores_list  mean_similarity_score  \
# 0    [0.02697621518236352, 0.0, 0.03242136805362899...               0.018405
# 1    [0.007197123322763255, 0.0051736136925291925, ...               0.058451
# 2    [0.01044065185339305, 0.0, 0.02950585563320733...               0.009337
# 3    [0.012281415239966146, 0.02696491648561693, 0....               0.066646
# 4    [0.00340888102818777, 0.02332300161231656, 0.0...               0.015926
# ..                                                 ...                    ...
# 995  [0.0426236394204663, 0.02526529716731194, 0.00...               0.019403
# 996  [0.02398428888624259, 0.020906982781366244, 0....               0.010759
# 997  [0.0, 0.015102355213715836, 0.0, 0.02371667758...               0.006078
# 998  [0.011927089756086478, 0.01132274443756136, 0....               0.012094
# 999  [0.020676692215979318, 0.026918746933448458, 0...               0.018199
#
#                              max_similarity_score  num_exact_matches
# 0      [0.03242136805362899, 0.03906784168008337]                  0
# 1      [0.007197123322763255, 0.5127871656196451]                  0
# 2    [0.029505855633207338, 0.018733342147202403]                  0
# 3        [0.5127871656196451, 0.0517584584988947]                  0
# 4       [0.02332300161231656, 0.0517584584988947]                  0
# ..                                            ...                ...
# 995    [0.0426236394204663, 0.028494710116081803]                  0
# 996   [0.02561423259626288, 0.007984469981907565]                  0
# 997  [0.023716677584827726, 0.006018297839707198]                  0
# 998  [0.029593441500958117, 0.019991562840876765]                  0
# 999     [0.0517584584988947, 0.04519524332308271]                  0
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Evaluation

# %%
output_df['mean_similarity_score'].describe()
# Out:
# count    1000.000000
# mean        0.018003
# std         0.018727
# min         0.000000
# 25%         0.008647
# 50%         0.012214
# 75%         0.016738
# max         0.112852
# Name: mean_similarity_score, dtype: float64

# %%
total_books = 2000
total_hits = output_df['num_exact_matches'].sum()
print(total_hits)
accuracy_of_exact_hits = total_hits/total_books * 100 # checking for accuracy of recommendation. hits/total_books
print(f"The accuracy of the recommendation system in terms of exact match is {accuracy_of_exact_hits:.2f}%")
# Out:
# 0
# The accuracy of the recommendation system in terms of exact match is 0.00%
