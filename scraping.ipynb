# %% [markdown]
# ## Web Scraping for Category of Books using ISBN

# %%
import requests
import pandas as pd 
import json
from bs4 import BeautifulSoup

# %%
def load_data(file_name):
    data = []
    with open(file_name, 'r') as fin:
        for l in fin:
            d = json.loads(l)
            data.append(d)
    return data

# %%
API_KEY = 'AIzaSyBwMyvFWyI3RYMhsEJVDryAP5RgM0L5874' # Replace with your API key

def get_book_category_by_isbn(isbn):
    # url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}&key={API_KEY}'
    url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}'
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if 'items' in data:
            book = data['items'][0]
            volume_info = book.get('volumeInfo', {})
            categories = volume_info.get('categories', 'No categories found')
            return categories
        else:
            return 'No book found'
    else:
        return f'Error: {response.status_code}'

# %%
df_children_books = load_data('goodreads_books_children.json')
df_children_books = pd.DataFrame(df_children_books)

# %%
isbn_list = df_children_books['isbn'].tolist()

# %%
categories_dict = {}

for isbn in isbn_list:
    categories = get_book_category_by_isbn(isbn)
    categories_dict[isbn] = categories
# Out:
# ['Juvenile Fiction']
# ['Juvenile Fiction']
# ['Juvenile Fiction']
# ['Fiction']
# ['Juvenile Nonfiction']
# ['Juvenile Fiction']
# No categories found
# ['Books and reading']
# No categories found
# ['Juvenile Nonfiction']
# ['Juvenile Nonfiction']
# ['Juvenile Nonfiction']
# No categories found
# ['Grandfathers']
# ['Juvenile Fiction']
# ['Amusement parks']
# ['Juvenile Fiction']
# ['Juvenile Fiction']
# No categories found
# ["Children's stories"]
# No categories found
# ['Boarding schools']
# ['Reference']
# No categories found
# ['Pilgrims (New Plymouth Colony)']
# No categories found
# ["Children's stories"]
# ['Fiction']
# ['Juvenile Fiction']
# ['Juvenile Fiction']
# ["Children's stories, English"]
# ['Christmas stories']
# ['Agricultural exhibitions']
# ['Juvenile Nonfiction']
# ['Juvenile Nonfiction']
# No categories found
# ['Juvenile Fiction']
# ['Juvenile Fiction']
# No categories found
# No book found
# ['African Americans']
# No categories found
# ['Persian poetry']
# ...

# %%
# # Example usage
# isbn = '1599150603'  # Replace with any ISBN you want
# title, categories = get_book_category_by_isbn(isbn)

# if title:
#     print(f"Book: {title}")
#     print(f"Categories: {categories}")
# else:
#     print(categories)
# Out:
# Book: The Aeneid for Boys and Girls
# Categories: ['Juvenile Fiction']
